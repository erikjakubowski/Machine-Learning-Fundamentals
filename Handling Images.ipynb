# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
#load image for preprocessing
image = cv2.imread("Resources/full.jpg", cv2.IMREAD_GRAYSCALE)
plt.imshow(image,cmap="gray"), plt.axis("off")
plt.show()

# %%
#work with image as np array using imread
#numpy.ndarray
type(image)

#view matrix
image

# #dimensions
# image.shape

# #first pixel 1110/1435
# image[,2]
# Out:
# array([[ 61,  65,  64, ..., 173, 131, 102],
#        [ 61,  64,  64, ..., 169, 130, 100],
#        [ 68,  65,  64, ..., 160, 129, 100],
#        ...,
#        [ 48,  51,  53, ..., 128, 136, 135],
#        [ 49,  53,  54, ..., 123, 133, 134],
#        [ 50,  53,  55, ..., 117, 128, 130]], dtype=uint8)

# %%
#load image with color
image_color = cv2.imread("Resources/full.jpg", cv2.IMREAD_COLOR)
#blue green red value
image_color[0,0]


image_color = cv2.cvtColor(image_color, cv2.COLOR_BGR2RGB)

# Show image
plt.imshow(image_color), plt.axis("off")
plt.show()

# %%
image_color = cv2.imread("Resources/full.jpg", cv2.COLOR_BGR2RGB)
image_color.shape
# Out:
# (1110, 1435, 3)

# %%
# Load image
image_bgr = cv2.imread("Resources/idk.jpg")

# Convert BGR to HSV
image_hsv = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2HSV)

# Define range of blue values in HSV
lower_blue = np.array([0,10,150])
upper_blue = np.array([130,200,255])

# Create mask
mask = cv2.inRange(image_hsv, lower_blue, upper_blue)

# Mask image
image_bgr_masked = cv2.bitwise_and(image_bgr, image_bgr, mask=mask)

# Convert BGR to RGB
image_rgb = cv2.cvtColor(image_bgr_masked, cv2.COLOR_BGR2RGB)

# Show image
plt.imshow(image_rgb), plt.axis("off")
plt.show()
